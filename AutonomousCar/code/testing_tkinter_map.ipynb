# %%
import tkinter
import tkintermapview

# %%
from data_collect_GUI import GUI

gui = GUI()
gui.run()

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import serial
import numpy as np
import time
import pandas as pd

class GUI:
    def __init__(self, s_port='com20', baud=9600, max_val = 100):
        self.start_time = time.time()
        self.ser = serial.Serial()
        ser_open = False
        attempts = 0

        #attempt to connect
        while not ser_open and attempts < 5:
            try:
                self.ser = serial.Serial(s_port, baud, timeout=None)
                ser_open = True
            except:
                print("Failed to open serial port: ", attempts)
                
            if not ser_open:
                # self.ser.close()
                # print("Closed Serial Port")
                time.sleep(0.1)
                attempts += 1
        
        # verify the serial port is open
        if not ser_open:
            print("Failed to open serial port - closing")
            return
        
        # serial port is open - create the main application window
        self.root = tk.Tk()
        self.root.title("Real-time Serial Plotter")

        self.top_frame = tk.Frame(self.root)
        self.top_frame.pack()
        self.mid_frame = tk.Frame(self.root)
        self.mid_frame.pack(side=tk.TOP)
        self.btm_frame = tk.Frame(self.root)
        self.btm_frame.pack(side=tk.BOTTOM)

        self.t = 0.0
        self.dt = 0.01
        self.speed_input_pwm = 1500
        self.steer_input_pwm = 1500
        self.speed_input_pwms = []
        self.steer_input_pwms = []

        self.max_vals = max_val

        self.pwm_df = pd.DataFrame(columns=['time', 'status', 'steer', 'throttle', 'control'])
        self.pwm_times = []
        self.throttles = []
        self.steers = []
        self.statuses = []
        self.controls = []
        
        self.df = pd.DataFrame(columns=['time', 'lat', 'lon', 'alt', 'speed', 'heading', 'fusion_calibration'])
        self.gps_times = []
        self.lats = []
        self.lons = []
        self.alts = []
        self.speeds = []
        self.headings = []

        # create a list of figure and axes objects to plot the data
        self.figures = []
        self.axes = []
        self.n_figures = 4
        for _ in range(self.n_figures):
            fig = Figure(figsize=(4, 2), dpi=100)
            ax = fig.add_subplot(1, 1, 1)
            ax.grid()
            self.figures.append(fig)
            self.axes.append(ax)

        # create a list of canvas objects for the plots and add them to the window
        self.canvases = []
        for fi, fig in enumerate(self.figures):
            if fi % 2 == 0:
                canvas = FigureCanvasTkAgg(fig, master=self.top_frame)
            else:
                canvas = FigureCanvasTkAgg(fig, master=self.mid_frame)
            canvas.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
            self.canvases.append(canvas)


        self.entry_canvas = tk.Canvas(self.btm_frame, width=600, height=300)

        self.speed_label = tk.Label(self.btm_frame, text="Enter Speed Command (900-2100)")
        self.entry_canvas.create_window(150,60,window=self.speed_label)

        self.speed_entry = tk.Entry(self.root)
        self.entry_canvas.create_window(300,60, window=self.speed_entry)

        label_widget2 = tk.Label(self.btm_frame, text="Enter Steer Command (900-2100)")
        self.entry_canvas.create_window(150,100,window=label_widget2)

        self.steer_entry = tk.Entry(self.btm_frame)
        self.entry_canvas.create_window(300,100, window=self.steer_entry)

        self.submit_button = tk.Button(text='Submit', command=self.submit_data)
        self.entry_canvas.create_window(225,150, window=self.submit_button)
        
        self.reset_button = tk.Button(text='Reset', command=self.reset_data)
        self.entry_canvas.create_window(225,200, window=self.reset_button)
        
        self.oval = self.entry_canvas.create_oval(50, 50, 0, 100)  # Create a circle on the Canvas

        self.entry_canvas.pack(side=tk.LEFT, fill=tk.BOTH)

        
        self.median_text = tk.StringVar()
        self.median_text.set("Median Throttle Command: " + str(np.median(self.throttles)) + "\nMedian Steer Command: " + str(np.median(self.speeds)))
        self.label = tk.Label(self.root, textvariable=self.median_text)
        self.label.pack()
    
    def submit_data(self):
        try:
            speed_pwm_in = int(self.speed_entry.get())
            steer_pwm_in = int(self.steer_entry.get())
            
            if speed_pwm_in >= 900 and speed_pwm_in <= 2100:
                self.speed_input_pwm = speed_pwm_in
                
            if steer_pwm_in >= 900 and steer_pwm_in <= 2100:
                self.steer_input_pwm = steer_pwm_in
        
        except:
            tk.messagebox.showinfo('Error', "Your data was not formatted properly")  
        
        self.speed_entry.delete(0, tk.END)
        self.steer_entry.delete(0, tk.END)

    def reset_data(self):
        self.steer_input_pwm = 1500
        self.speed_input_pwm = 1500

    # create a function to read the serial data and update the plots
    def update_plots(self):
        try:
            # capture time
            c_time = time.time() - self.start_time
            # read the serial data
            while self.ser.in_waiting:
                bytes = self.ser.readline()
                # print("bytes: ", bytes)
                try:
                    decoded_strings = str(bytes[0:len(bytes)-2].decode("utf-8")).split(',')
                    # print("decoded_strings: ", decoded_strings)
                    if decoded_strings[0] == 'G':
                        decoded_strings[0] = c_time
                        # print("GPS: ", decoded_strings)
                        self.gps_ingest_line(decoded_strings)
                    elif decoded_strings[0] == 'P':
                        decoded_strings[0] = c_time
                        # print("PWM: ", decoded_strings)
                        self.pwm_ingest_line(decoded_strings)
                    elif decoded_strings[0] == 'E':
                        print("ERR: ", decoded_strings)
                    else:
                        print("Error: BAD STRING: ",  decoded_strings)
                except:
                    print("GUI didn't log Serial RF message correctly: ", bytes)
            
            
            if self.controls[-1] > 1700:
                self.entry_canvas.itemconfig(self.oval, fill="green")
            else:
                self.entry_canvas.itemconfig(self.oval, fill="red")
                
            self.axes[0].clear()
            self.axes[0].plot(self.pwm_times, self.throttles, label="Received")
            # self.axes[0].plot(self.pwm_times, self.controls, label="Control")
            self.axes[0].plot(self.pwm_times, self.speed_input_pwms, label="Set")
            self.axes[0].grid()
            self.axes[0].set_ylabel("Speed PWM")
            self.axes[0].set_title("Speed Commands vs Time")
            self.axes[0].legend(loc='upper left')
            self.axes[0].set_ylim([900, 2100])
            
            
            self.axes[1].clear()
            self.axes[1].plot(self.gps_times, self.speeds, label="Speed")
            self.axes[1].grid()
            self.axes[1].set_ylabel("Speed (m/s)")
            self.axes[1].set_title("Vehicle Speed vs Time")
            # axes[1].legend()
            self.axes[1].set_ylim([-5, 15])
            
            
            self.axes[2].clear()
            self.axes[2].plot(self.pwm_times, self.steers, label="Received")
            # self.axes[2].plot(self.pwm_times, self.controls, label="Control")
            self.axes[2].plot(self.pwm_times, self.steer_input_pwms, label="Set")
            self.axes[2].grid()
            self.axes[2].set_ylabel("Steering PWM")
            self.axes[2].set_title("Steering Commands vs Time")
            self.axes[2].legend(loc='upper left')
            self.axes[2].set_ylim([900, 2100])
            
            
            self.axes[3].clear()
            self.axes[3].plot(self.gps_times, self.headings, label='Heading')
            self.axes[3].grid()
            self.axes[3].set_ylabel("Heading (Degs)")
            self.axes[3].set_title("Heading Rate vs Time")
            # axes[3].legend()
            self.axes[3].set_ylim([0.0, 360.0])
            
            self.median_text.set("Median Throttle Command: " + str(np.median(self.throttles)) + "\nMedian Steer Command: " + str(np.median(self.speeds)))
            
            # update the plots on the canvases
            for canvas in self.canvases:
                canvas.draw()
        except:
            pass
        
        # schedule the function to run again after 100ms
        self.root.after(int(self.dt*1000), self.update_plots)
        
    def pwm_ingest_line(self, line):
            # [0.01695728302001953, '1', '-1', '1502', '1497', '$']
            # print("pwm line: ", line)
            # print("time: ", line[0])
            line[1] = float(line[1])
            # print("status: ", line[1])
            line[2] = float(line[2]) / 10**3
            # print("Time: ", line[2])
            line[3] = float(line[3])
            # print("control: ", line[3])
            line[4] = float(line[4])
            # print("steer: ", line[4])
            line[5] = float(line[5])
            # print("throttle: ", line[5])            
            
            # print("line: ", line)
            # self.pwm_df.loc[len(self.pwm_df)] = line[:-1]
            
            # append for plotting
            self.statuses.append(line[1])
            self.pwm_times.append(line[2])
            self.controls.append(line[3])
            self.steers.append(line[4])
            self.throttles.append(line[5])
            # track gui inputs here too
            self.speed_input_pwms.append(self.speed_input_pwm)
            self.steer_input_pwms.append(self.steer_input_pwm)
            

            while len(self.pwm_times) > self.max_vals:
                self.pwm_times.pop(0)
            while len(self.statuses) > self.max_vals:
                self.statuses.pop(0)
            while len(self.controls) > self.max_vals:
                self.controls.pop(0)
            while len(self.steers) > self.max_vals:
                self.steers.pop(0)
            while len(self.throttles) > self.max_vals:
                self.throttles.pop(0)

            while len(self.speed_input_pwms) > self.max_vals:
                self.speed_input_pwms.pop(0)
            while len(self.steer_input_pwms) > self.max_vals:
                self.steer_input_pwms.pop(0)
        
    def gps_ingest_line(self, line):
            # print("gps line: ", line)
            # ['G', '394265191', '-1198031066', '1466181', '18', '0', '0', '$']
            line[1] = float(line[1]) / 10**3
            line[2] = float(line[2]) / 10**7
            # print("lat: ", line[1])
            line[3] = float(line[3]) / 10**7
            # print("lon: ", line[2])
            line[4] = float(line[4]) / 10**3
            # print("alt: ", line[3])
            line[5] = float(line[5]) / 10**3
            # print("speed: ", line[4])
            line[6] = float(line[6]) / 10**5
            # print("heading: ", line[5])
            # print("cal status: ", line[6])
            
            # self.gps_df.loc[len(self.gps_df)] = line[:-1]
            
            self.gps_times.append(line[1])
            self.lats.append(line[2])
            self.lons.append(line[3])
            self.alts.append(line[4])
            self.speeds.append(line[5])
            self.headings.append(line[6])
            
            while len(self.gps_times) > self.max_vals:
                self.gps_times.pop(0)
            while len(self.lats) > self.max_vals:
                self.lats.pop(0)
            while len(self.lons) > self.max_vals:
                self.lons.pop(0)
            while len(self.alts) > self.max_vals:
                self.alts.pop(0)
            while len(self.speeds) > self.max_vals:
                self.speeds.pop(0)
            while len(self.headings) > self.max_vals:
                self.headings.pop(0)

    def run(self):
        # start the function to update the plots
        self.update_plots()

        # start the main event loop
        self.root.mainloop()
        
    def __del__(self):
        try:
            self.ser.close()
            print("Closed Serial Port")
        except:
            print("Failed to close serial port")

if __name__ == "__main__":

    gui = GUI(max_val = 100)
    gui.run()
# Out:
# c:\Users\sgtas\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\sgtas\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# GUI didn't log Serial RF message correctly:  b'P,1,520\xffP,1,1697,1505,14\xf6P,1,1653,1503,1458,1536,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,75760,352,1558,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,897850270,1379559,3133,9884390,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,817850199,1379597,3191,9865208,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,82280,394390468,-1159,1548,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,8\x13b\x8a\xaa\xaa\x9ab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,88878\r\n'
# GUI didn't log Serial RF message correctly:  b'G,89258,394391107,-119785116583316,0,$\r\n'
# Error: BAD STRING:  ['P$']
# GUI didn't log Serial RF message correctly:  b'P,1,92623,1502577,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,92679,394390697,-1197850938804,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,93184,1505,1445$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,93272,1505,1452,1M,394390848,-1197850754,1382006,4470,3726344,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,9305,1453,1579,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,93524,1506,1455390948,-119785065R\xaa\x82\xb2b\x8a\xa2\xca\x8ab\x8a\xaa\xb2\xc2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,93)b"j\n'
# Error: BAD STRING:  ['0', '96087', '1502', '1513', '1559', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,100839,1506,1496,1535\xd3894,1502,1507,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,101862,150L\x8a\xaa\xa2\x8ab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1027,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1\x8a\x8a\xaa\xca\xb2b\x8a\xaa\xaa\xb2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1\x08\x9ab\x8a\xaa\xc2\xb2b\x8a\xaa\xaa\xcab"j\n'
# GUI didn't log Serial RF message correctly:  b'\xb248,1506,1476,1565,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,104271,1505\n'
# GUI didn't log Serial RF message correctly:  b'H\x82\x92b\x8a\xaa\x8a\xb2b\x8a\xaa\xa2\xaab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,105877,150\x8a,105932,1503,1443,1558,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1060\x13\x8a\xaa\xb2\x8ab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,106383,1503,1458,156\x929,1505,1458,1561,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,106482,150\xb2\xc2b\x8a\xaa\xb2\x92b"j\n'
# Error: BAD STRING:  ['P5', '106625', '1503', '1459M812', '1506', '1444', '1560', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,107351,1502,1448,1)07417,1505,1444,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,11645\n'
# Error: BAD STRING:  ['506', '1444', '1534', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,1271\xc5b\x8a\x92\x82\xbab\x8a\xaa\x9a\xa2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,0,1535,0,0,\xb0G,1732,394392040,-1197850368,1373623,154,16108659,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,61669,394391064,-1197851157,1379,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,86978,394390984,-1197851227,1375,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,0,8726G,87376,394390939,-1197851262,1375601,1435,20011166,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,91976,394390478247,1329,22364997,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,92170,394390465,-1197851727,1376140,1525,23179247P,0,92276,-1,-1,-1,$\r\n'
# Error: BAD STRING:  ['590', '1457', '23528887G', '94165', '394390301', '-1197851961', '1376621', '1422', '24143595', '0', '$']
# GUI didn't log Serial RF message correctly:  b'P,0,95783,-1,-1,-G,95910,394390220,-1197852163,1376535,1171,27150137,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,98476,394390280,-1197852524,1376014,1027,29601738G,98680,394390290,-1197852543,1375927,1038,30384749,0,$\r\n'
# Error: BAD STRING:  ['8', '-1197852220', '1375464', '1398', '1010406-1', '-1', '-1', '$']
# GUI didn't log Serial RF message correctly:  b'G,124491,394391408,-1197850656,1371776,1323,2662598G,124817,394391394,-1197850700,1371713,1381,24168663,0,$\r\n'
# Error: BAD STRING:  ['9', '-1197850443', '1371268', '1134', '10710815', '0', '$']
# GUI didn't log Serial RF message correctly:  b'\xca\x8a\x9a\xb2\xb2\xba\xb2\xb2b\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'\x9a\x9ab\x8a\x8a\x9a\xb2\xb2\xba\xb2\xb2b\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,273\xc2\xa2\x9ab"j\n'
# GUI didn't log Serial RF message correctly:  b'G,273884,3943\xca"j\n'
# GUI didn't log Serial RF message correctly:  b'P,,1576,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,275608,14053978,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,275876,394390935,-11978510962313,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,27608H\x82\x9ab\x8a\x9a\x8a\xaab\x8a\xaa\xba\x92b"j\n'
# GUI didn't log Serial RF message correctly:  b'G,276265,394\xa2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,276960,1505,1512,1\x8a,1,277026,1503,15Lb"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,S277648,394391369,-1197850581,137641\x92\n'
# GUI didn't log Serial RF message correctly:  b'P,1,278666,150Lb"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,278786,151,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,279479,394391330,-1197849932,1376103,3333,\xca\xa2\x8ab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,279600,1505,\x13\n'
# GUI didn't log Serial RF message correctly:  b'P,1\xca\x8a\xaa\xa2\xb2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,28002"1506,1588,1558,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,2800236,21282032,0,$\r10304,1506,1586,15bP,1,280359,1506,1583,1557,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,280447,1503,i\xba\xc2\xaa\x82\x82\xca\xcab\x8a\x9a\xba\xb2\x8a\xb2\xbab\x9a1,1,280601,1505,1581,1561,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,281077,1502368,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,281892,15\xca\x8a\xaa\xba\xbab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,286144,15051557,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,286210,1506,1265,1560,\x92,1,286265,1505,12\xd3\x9a\xb2\x9a\x82\xc2b\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,28\xd328,1503,1230,1556386687,394390920,-,1233,1549,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1549,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,21197851582,1376981,2141,14779141,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,28505,1440,1598,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,288861,1505,1428,158\x9a\xa2\xa2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,288982,\xb1,1437,1533,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1\x9a158,1505,1447,153\x92\x8a\xaa\x9a\xaab"j\n'
# GUI didn't log Serial RF message correctly:  b'G,289453,\x9a\xaa\x8a\xc2\xb2\xcab\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'G,289873,394390734,-116159,8518524,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,234,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,29146811440,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'\x9a\x82\x82\xc2\xaa\xca\xc2b\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,293822,1502,1321,,1505,1298,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,294574,394391033,-1197851248,1377743,3\n'
# GUI didn't log Serial RF message correctly:  b'G,295476,394390803,-1197851297,1377,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,298,1602,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,295898,394390739\xc2\xca\xb2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,296000,,6,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,296055,1\xb2b\x8a\xaa\xca\xaab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2961\x133,1505,1452,1597,71,1377872,4925,9357696,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,29\x08\x9ab\x8a\xa2\xaa\xc2b\x8a\xaa\xca\xcab"j\n'
# GUI didn't log Serial RF message correctly:  b'G,\x92\n'
# GUI didn't log Serial RF message correctly:  b'P,1,296473,1506,R\xaa\x82\xb2b\x8a\xa2\xa2\xb2b\x8a\xaa\xc2\xc2b"j\n'
# GUI didn't log Serial RF message correctly:  b'G,296590,394390704,-1197850756,137393,1533,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2b,1503,1263,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,297254,1502M\xaa\xca\x9ab\xca\xa2\x82\xa2\xc2\xaa\xcab\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,297281,1502,1\xbab\x8a\xaa\x9a\xa2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2974\x13b\xc2\xb2\x92\xaa\xb2\x82\x82b\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,11297793,1502,1253,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,297826,353,1534,$\r\n'
# Error: BAD STRING:  ['51', '394390844', '-1197849788', '1377796', '461)b"']
# GUI didn't log Serial RF message correctly:  b'P,1,298156,15b\x9a\xa2\xc2\x82\x92\xa2\xaa\x8ab\x82b"j\n'
# Error: BAD STRING:  ['6', '-1197851353', '1378239', '1533', '$']
# GUI didn't log Serial RF message correctly:  b'G,30197851324,1378869,4501,15319668,0,$\r\n'
# Error: BAD STRING:  ['1197850927', '1379013', '3149', '2136981', '0', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,304751,1506,)P,1,304931,1505,1488,1567,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,30\r505,1483,1565,$\r\n'
# Error: BAD STRING:  ['']
# GUI didn't log Serial RF message correctly:  b'P,1,314501,1506,1454,1548b,1503,1453,1549,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,13,1448,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1533,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,355782,1502,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,355881,150,1535,$\r\n'
# Error: BAD STRING:  ['P67', '1534', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,356332,1P,1,356365,1505,1467,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,356420,P,1,356453,1506,156474,1505,1467,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,533346,1\xf5P,1,533,1505,1460\xfcG,566,394392345,-1197850144,1367671,3,11179169,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,4880,1506,4,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1016P,1,2187,1503,1456,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P\xfeP,1,1755,1503,1457,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,\xfeG,703,394392237,-11\xffG,694,394391381,-1197850716,1373968,170,11178979,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,102$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1505,1603,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,66694,394392201,-1197849986,,1503,1464,1535,$6820,1505,1462,1536,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,90104,39439989,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,558,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,91128,1503565,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,91420,394391028,-11978512153886,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,91596,394391371088,2737,8791436,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,b,1503,1509,1542,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,94626,\n'
# GUI didn't log Serial RF message correctly:  b'P,1,9R\x82\xb2b\x8a\xaa\xa2\xcab\x8a\xaa\x9a\xbab"j\n'
# Error: BAD STRING:  ['P5', '1536', '$']
# GUI didn't log Serial RF message correctly:  b'G,10366852188,1373051,1683,24065580,0,$\r\n'
# Error: BAD STRING:  ['P76', '1547', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,104082\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1559,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,104685,394390772,-1197889,1559,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,105078,1502,1260,1\n'
# GUI didn't log Serial RF message correctly:  b'G,105289,394390706,-1197852145,13\r\n'
# GUI didn't log Serial RF message correctly:  b'G,106280,394391373253,3916,7056515,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1066$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,107814,1503,1374,1534\x8994390992,-1197851083,1372997,4543,5126223,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,108023,1502,1458,1L,108080,394391048,-1197851011,1372975,4511,3990696,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,113226,1503,1546,,1506,1541,1553,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,113413,1506,1548,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,113494,394390851,-3,1548,1551,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,2,1552,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1132,$\r\n'
# Error: BAD STRING:  ['556', '1559', '$']
# Error: BAD STRING:  ['1432', '1506', '1294', '151505', '1289', '1534', '$']
# Error: BAD STRING:  ['280', '1534', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,1\n'
# GUI didn't log Serial RF message correctly:  b'G,121879,394390845,-1197851518,1373958$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,122576,448,1569,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,11505,1454,1566,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,3,4174,9849647,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1561,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,131,1505,1397,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,124864,150-1197850290,1373931,4414,9448139,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,125068,394390586,-1197850185,137387$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1258,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,125875,150,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,3,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,6,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,12690802,-1197849631747,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,126777,1503,139,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,126866,394390921,-1197849578,13736,$\r\n'
# Error: BAD STRING:  ['P19', '1564', '$']
# GUI didn't log Serial RF message correctly:  b'G,135485,394391188,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,136478,39439174601,3903,10095552,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,138672,394390986,-1197849743,13740,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,139581,1505,1340,$\r\n'
# Error: BAD STRING:  ['393', '1542', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,14503,1474,1566,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,14803$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,148068,39439375798,3857,8978500,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,148878,394391182,-1197850357,73,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,149506,394391337,-1197850323,1375702,3454,333852\x13j\n'
# GUI didn't log Serial RF message correctly:  b'G,151708,394391791,-1197851014,1375679,2053,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1570,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,153855,1602,1575,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,15488$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,16047549683,1376141,4040,19484936,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1604,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,161228\r\n'
# Error: BAD STRING:  ['515', '1583', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,184,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,16288850553,1375821,5349,32959418,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,163009,1P,1,163043,1503,1501,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,163067,394391241,-1197850586,1375763,5P,1,163067,1502,1495,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,168670,394391154,-1197851396,1649,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1686$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,168882,394391140,-1197851329,13792$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1706,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,174873,394391038,-119783,26746482,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,175079,39437,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1758,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,,1550,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,178095,394390983100,2253,25804207,0,$\r\n'
# Error: BAD STRING:  ['442', '1557', '$']
# GUI didn't log Serial RF message correctly:  b'G,17887952307,1378217,2394,24959586,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,180961,150,1558,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1556,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1844,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,184579,1P,1,184612,1503,1442,1545,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,184670,394390815,-119785381506,1513,1546,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1852,$\r\n'
# GUI didn't log Serial RF message correctly:  b'G,192692,394391377806,1351,28978148,0,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,213860,1503,1444,1663,$\x8a\xcab\x8a\xc2\x9a\x92\x92\x92\x82\xbab\x82b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,214795,1503,1447,$\r\n'
# Error: BAD STRING:  ['P48', '1617', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,215609,1503\x92\n'
# GUI didn't log Serial RF message correctly:  b'P,,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2164,$\r\n'
# Error: BAD STRING:  ['453', '1534', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,211503,1454,1534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1502,$\r\n'
# Error: BAD STRING:  ['P12', '1519', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,217600,136,1509,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,21579,1533,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,218029,1506,1595,,1505,1598,1532,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,21815\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,218656,1502,164,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,21P,1,218843,1505,118865,1503,1699,1533,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,21926,1502,1536,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,,1602,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2194,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,536,1505,1460,1611,$\r\n'
# Error: BAD STRING:  ['9800', '1503', '1466', '1617', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,607,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2201081534,1596,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,22038$\r\n'
# Error: BAD STRING:  ['P46', '1592', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,220767-\xf4505,1436,1589,$\r\n'
# Error: BAD STRING:  ['98', '1592', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,220954,\n'
# GUI didn't log Serial RF message correctly:  b'P,1,22140$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1581,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2210,$\r\n'
# Error: BAD STRING:  ['1944', '1502', '1407', '1590', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,2582,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,222153\n'
# GUI didn't log Serial RF message correctly:  b'P,1,1573,$\r\n'
# Error: BAD STRING:  ['P814', '1502', '1403', '1577', '$']
# GUI didn't log Serial RF message correctly:  b'P,1,2580,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2579,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,225288,1505,1489,)25354,1502,1475,1535,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,225387,b\xa2\x9a\x8ab\x8a\xaa\x9a\xa2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,225475,\n'
# GUI didn't log Serial RF message correctly:  b'P,1,2534,$\r\n'
# GUI didn't log Serial RF message correctly:  b'P,1,226619,1505,&b\x8a\xaa\x9a\xa2b"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,228214,1502,)\x8a\xa2\x9a\xcab\x8a\x92\x9a\x9ab"j\n'
# GUI didn't log Serial RF message correctly:  b'P,1,\xa6401,1505,1429,1227,$\r\n'
